# %%
# %run ../src/preprocess.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
sns.histplot(df['Species'])
plt.show()

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.histplot(df["SepalLengthCm"],kde=True)
print("SepalLengthCm =",df["SepalLengthCm"].skew())
plt.show()

sns.histplot(df["SepalWidthCm"],kde=True)
print("SepalWidthCm =",df["SepalWidthCm"].skew())
plt.show()

sns.histplot(df["PetalLengthCm"],kde=True)
print("PetalLengthCm =",df["PetalLengthCm"].skew())
plt.show()

sns.histplot(df["PetalWidthCm"],kde=True)
print("PetalWidthCm =",df["PetalWidthCm"].skew())
plt.show()
# Out:
# SepalLengthCm = 0.3149109566369728
# SepalWidthCm = 0.3340526621720866
# PetalLengthCm = -0.27446425247378287
# PetalWidthCm = -0.10499656214412734
